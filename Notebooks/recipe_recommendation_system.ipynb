# %% [markdown]
# # Recommendation

# %% [markdown]
# # Step 1: Load the Dataset

# %%
import pandas as pd

# Load the dataset
file_path = 'recipe_cleaned.csv'
recipe_df = pd.read_csv(file_path)

recipe_df.head()
# Out:
#    Unnamed: 0  recipe_id                                 recipe_name  \
# 0           0     137739  arriba   baked winter squash mexican style
# 1           1      31490            a bit different  breakfast pizza
# 2           2     112140                   all in the kitchen  chili
# 3           3      59389                          alouette  potatoes
# 4           5      25274                       aww  marinated olives
#
#                                     ingredients_list  minutes  n_steps  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...       55       11
# 1  ['prepared pizza crust', 'sausage patty', 'egg...       30        9
# 2  ['ground beef', 'yellow onions', 'diced tomato...      130        6
# 3  ['spreadable cheese with garlic and herbs', 'n...       45       11
# 4  ['fennel seeds', 'green olives', 'ripe olives'...       15        4
#
#                                      precedure_steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['toast the fennel seeds and lightly crush the...
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['15-minutes-or-less', 'time-to-make', 'course...
#
#                                          description  calories(in kcal)  \
# 0  autumn is my favorite time of year to cook! th...               51.5
# 1  this recipe calls for the crust to be prebaked...              173.4
# 2  this modified version of 'mom's' chili was a h...              269.8
# 3  this is a super easy, great tasting, make ahea...              368.1
# 4  my italian mil was thoroughly impressed by my ...              380.7
#
#    protein(in PDV)
# 0              2.0
# 1             22.0
# 2             39.0
# 3             14.0
# 4              6.0

# %%
len(recipe_df)
# Out:
# 178023

# %%
recipe_df= recipe_df.drop(columns='Unnamed: 0')

# %%
recipe_df.columns
# Out:
# Index(['recipe_id', 'recipe_name', 'ingredients_list', 'minutes', 'n_steps',
#        'precedure_steps', 'tags', 'description', 'calories(in kcal)',
#        'protein(in PDV)'],
#       dtype='object')

# %%
recipe_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178023 entries, 0 to 178022
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   recipe_id          178023 non-null  int64
#  1   recipe_name        178023 non-null  object
#  2   ingredients_list   178023 non-null  object
#  3   minutes            178023 non-null  int64
#  4   n_steps            178023 non-null  int64
#  5   precedure_steps    178023 non-null  object
#  6   tags               178023 non-null  object
#  7   description        178023 non-null  object
#  8   calories(in kcal)  178023 non-null  float64
#  9   protein(in PDV)    178023 non-null  float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 13.6+ MB

# %%
recipe_df.describe()
# Out:
#            recipe_id        minutes        n_steps  calories(in kcal)  \
# count  178023.000000  178023.000000  178023.000000      178023.000000
# mean   227797.684726      38.086450       8.787219         314.115567
# std    139085.391976      26.071078       4.389725         203.118282
# min        40.000000       0.000000       0.000000           0.000000
# 25%    108469.500000      20.000000       5.000000         157.200000
# 50%    215661.000000      31.000000       8.000000         275.300000
# 75%    338013.000000      50.000000      12.000000         431.650000
# max    537716.000000     132.000000      21.000000         988.900000
#
#        protein(in PDV)
# count    178023.000000
# mean         24.274554
# std          23.947340
# min           0.000000
# 25%           6.000000
# 50%          14.000000
# 75%          39.000000
# max          96.000000

# %% [markdown]
# ## Necessary Imports

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### Vectorizer

# %%
# Preprocess Ingredients
vectorizer = TfidfVectorizer()
X_ingredients = vectorizer.fit_transform(recipe_df['ingredients_list'][:50000])

# %%
X_ingredients.shape
# Out:
# (50000, 2969)

# %% [markdown]
# ### Normalization

# %%
# Normalize Numerical Features
scaler = StandardScaler()
X_numerical = scaler.fit_transform(recipe_df[['calories(in kcal)','protein(in PDV)', 'minutes', 'n_steps']][:50000])

# %% [markdown]
# ## KNN For the Recommendation

# %%
# Combine Features
X_combined = np.hstack([X_numerical, X_ingredients.toarray()])

# Train KNN Model
knn = NearestNeighbors(n_neighbors=3, metric='euclidean')
knn.fit(X_combined)
# Out:
# NearestNeighbors(metric='euclidean', n_neighbors=3)

# %% [markdown]
# ##  Main Recommendation Function

# %%
# Function to Recommend Recipes
def recommend_recipes(input_features):
    input_features_scaled = scaler.transform([input_features[:4]])
    input_ingredients_transformed = vectorizer.transform([input_features[4]])
    input_combined = np.hstack([input_features_scaled, input_ingredients_transformed.toarray()])
    distances, indices = knn.kneighbors(input_combined)
    recommendations = recipe_df.iloc[indices[0]]
    return recommendations[['recipe_name', 'ingredients_list', 'precedure_steps', 'description']]

# Example Input
input_features = [15, 36, 20, 15,'floor, pulse, chicken, tomatoes']
recommendations = recommend_recipes(input_features)
recommendations
# Out:
# c:\Users\RAVI TEJ\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
#                           recipe_name  \
# 32769  chicken   corn egg flower soup
# 29474                   ceviche tacos
# 21898          breakfast omelette  ww
#
#                                         ingredients_list  \
# 32769  ['fat free chicken broth', 'gingerroot', 'corn...
# 29474  ['limes', 'tomatoes', 'avocado', 'cilantro', '...
# 21898  ['eggs', 'egg whites', 'salt', 'pepper', 'onio...
#
#                                          precedure_steps  \
# 32769  ['place broth and ginger in medium saucepan', ...
# 29474  ['finely grate rind from limes to measure 1 ta...
# 21898  ['in a bowl whisk together eggs , egg whites ,...
#
#                                              description
# 32769  original recipe from kikkoman soy sauce, i cha...
# 29474  cerviche is a mexican appetizer, kind of like ...
# 21898  if following the ww flex plan this is 4 points...

# %% [markdown]
# ## Using Cosine Similarity for the Recommendation

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Function to Recommend Recipes Using Cosine Similarity
def recommend_recipes_cosine(input_features):
    # Scale and transform the input features
    input_features_scaled = scaler.transform([input_features[:4]])
    input_ingredients_transformed = vectorizer.transform([input_features[4]])
    input_combined = np.hstack([input_features_scaled, input_ingredients_transformed.toarray()])
    
    # Compute cosine similarity
    similarities = cosine_similarity(input_combined, X_combined)
    
    # Get top 3 recommendations
    top_indices = np.argsort(similarities[0])[-3:][::-1]  # Get indices of top 3 similar items
    recommendations = recipe_df.iloc[top_indices]
    
    return recommendations[['recipe_name', 'ingredients_list', 'precedure_steps', 'description']]

# Example Input
input_features = [15, 36, 15, 20, 'floor, vegitable, milk, pulse, tomatoes']
recommendations = recommend_recipes_cosine(input_features)
recommendations
# Out:
# c:\Users\RAVI TEJ\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
#                                              recipe_name  \
# 17677            betsy s really good tuna for sandwiches
# 241                       cheesecake factory  crab cakes
# 24123  build your own canadian cranberry and herb tur...
#
#                                         ingredients_list  \
# 17677  ['tuna in vegetable oil', 'dill pickle', 'cele...
# 241    ['lump crabmeat', 'plain breadcrumbs', 'mayonn...
# 24123  ['fresh breadcrumb', 'extra virgin olive oil',...
#
#                                          precedure_steps  \
# 17677  ['empty drained can of tuna into medium sized ...
# 241    ['measure all the ingredients for the crab cak...
# 24123  ['if grilling the burgers , preheat grill to m...
#
#                                              description
# 17677  tuna was something we ate a lot when i was a k...
# 241    be careful not to stir the crab too much into ...
# 24123  build your own burger - the recipe here is for...
